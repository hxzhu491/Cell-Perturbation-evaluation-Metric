# %% [markdown]
# # Overview
#
# - explore data sets from scgen paper
# - convert them to format that can be read in R
# - for informating on AnnData object, read this: https://scanpy.readthedocs.io/en/stable/usage-principles.html

# %%
# !pip install scanpy
import numpy as np
import scanpy
# Out:
# ...
#   Obtaining dependency information for scanpy from https://files.pythonhosted.org/packages/2f/9d/05129619c6bd9a657a64a9c19ec8d0eb46eb06c3107c48e38b1b6e70c088/scanpy-1.10.2-py3-none-any.whl.metadata
#   Using cached scanpy-1.10.2-py3-none-any.whl.metadata (9.3 kB)
# ...
#   Obtaining dependency information for anndata>=0.8 from https://files.pythonhosted.org/packages/ca/a2/52b1fb4d7bbb022929300a4351c363958c1377b33c0d0be94f803987af7a/anndata-0.10.9-py3-none-any.whl.metadata
#   Using cached anndata-0.10.9-py3-none-any.whl.metadata (6.9 kB)
# ...
#   Obtaining dependency information for legacy-api-wrap>=1.4 from https://files.pythonhosted.org/packages/97/08/eaf39f00542e4181b65617805f116a0d38daec98d0dce36ec94327ca8fc4/legacy_api_wrap-1.4-py3-none-any.whl.metadata
#   Using cached legacy_api_wrap-1.4-py3-none-any.whl.metadata (1.8 kB)
# ...

# %% [markdown]
# Kang data

# %%
dat = scanpy.read_h5ad("train_kang.h5ad")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 dat = scanpy.read_h5ad("train_kang.h5ad")
#
# File /Applications/anaconda3/lib/python3.11/site-packages/anndata/_io/h5ad.py:234, in read_h5ad(filename, backed, as_sparse, as_sparse_fmt, chunk_size)
#     226         raise NotImplementedError(
#     227             "Currently only `X` and `raw/X` can be read as sparse."
#     228         )
#     230 rdasp = partial(
#     231     read_dense_as_sparse, sparse_format=as_sparse_fmt, axis_chunk=chunk_size
#     232 )
# --> 234 with h5py.File(filename, "r") as f:
#     236     def callback(func, elem_name: str, elem, iospec):
#     237         if iospec.encoding_type == "anndata" or elem_name.endswith("/"):
#
# ...

# %%
dat
# Out:
# AnnData object with n_obs × n_vars = 16893 × 6998
#     obs: 'condition', 'n_counts', 'n_genes', 'mt_frac', 'cell_type'
#     var: 'gene_symbol', 'n_cells'
#     uns: 'cell_type_colors', 'condition_colors', 'neighbors'
#     obsm: 'X_pca', 'X_tsne', 'X_umap'
#     obsp: 'distances', 'connectivities'

# %%
dat.X
# Out:
# <16893x6998 sparse matrix of type '<class 'numpy.float32'>'
# 	with 5533579 stored elements in Compressed Sparse Row format>

# %%
dat.uns
# Out:
# {'cell_type_colors': array(['#1f77b4', '#ff7f0e', '#2ca02c', '#d62728', '#9467bd', '#8c564b',
#         '#e377c2'], dtype='<U7'),
#  'condition_colors': array(['#1f77b4', '#ff7f0e'], dtype='<U7'),
#  'neighbors': {'params': {'method': 'umap', 'n_neighbors': array([15])}}}

# %%
dat.var
# Out:
#                  gene_symbol  n_cells
# index
# AL627309.1        AL627309.1        8
# RP11-206L10.9  RP11-206L10.9       11
# LINC00115          LINC00115      118
# NOC2L                  NOC2L     1930
# KLHL17                KLHL17       28
# ...                      ...      ...
# SLC19A1              SLC19A1       81
# COL6A2                COL6A2       51
# FTCD                    FTCD        5
# DIP2A                  DIP2A      468
# S100B                  S100B      222
#
# [6998 rows x 2 columns]

# %%
dat.obs
# Out:
#                               condition  n_counts  n_genes  mt_frac  cell_type
# index
# AAACATACCAAGCT-1-stimulated  stimulated    1160.0      589      0.0         NK
# AAACATACCCCTAC-1-stimulated  stimulated    1729.0      795      0.0  Dendritic
# AAACATACCCGTAA-1-stimulated  stimulated    1360.0      585      0.0       CD4T
# AAACATACCCTCGT-1-stimulated  stimulated    1442.0      732      0.0          B
# AAACATACGAGGTG-1-stimulated  stimulated    1237.0      546      0.0       CD4T
# ...                                 ...       ...      ...      ...        ...
# TTTGACTGGCGGAA-1-control        control    2505.0      821      0.0       CD8T
# TTTGACTGTCGTAG-1-control        control    3704.0     1101      0.0  CD14+Mono
# TTTGACTGTTACCT-1-control        control    2133.0      629      0.0  CD14+Mono
# TTTGCATGCTTCGC-1-control        control    2317.0      875      0.0          B
# TTTGCATGGTCCTC-1-control        control    1250.0      531      0.0          B
#
# ...

# %%
dat.obs["cell_type"]
# Out:
# index
# AAACATACCAAGCT-1-stimulated           NK
# AAACATACCCCTAC-1-stimulated    Dendritic
# AAACATACCCGTAA-1-stimulated         CD4T
# AAACATACCCTCGT-1-stimulated            B
# AAACATACGAGGTG-1-stimulated         CD4T
#                                  ...
# TTTGACTGGCGGAA-1-control            CD8T
# TTTGACTGTCGTAG-1-control       CD14+Mono
# TTTGACTGTTACCT-1-control       CD14+Mono
# TTTGCATGCTTCGC-1-control               B
# TTTGCATGGTCCTC-1-control               B
# Name: cell_type, Length: 16893, dtype: category
# Categories (7, object): ['CD4T', 'CD14+Mono', 'B', 'CD8T', 'NK', 'FCGR3A+Mono', 'Dendritic']

# %%
dat.obs.describe(include='all')
# Out:
#          condition      n_counts       n_genes       mt_frac cell_type
# count        16893  16893.000000  16893.000000  16893.000000     16893
# unique           2           NaN           NaN           NaN         7
# top     stimulated           NaN           NaN           NaN      CD4T
# freq          8886           NaN           NaN           NaN      5564
# mean           NaN   2161.503174    737.418398      0.000002       NaN
# std            NaN   1045.748169    223.914479      0.000032       NaN
# min            NaN    678.000000    500.000000      0.000000       NaN
# 25%            NaN   1367.000000    560.000000      0.000000       NaN
# 50%            NaN   1845.000000    669.000000      0.000000       NaN
# 75%            NaN   2711.000000    857.000000      0.000000       NaN
# max            NaN  11814.000000   2755.000000      0.000996       NaN

# %%
dat.obs["cell_type"].value_counts()
# Out:
# CD4T           5564
# FCGR3A+Mono    3601
# CD14+Mono      2561
# B              1811
# NK             1163
# CD8T           1115
# Dendritic      1078
# Name: cell_type, dtype: int64

# %%
dat.obs
# Out:
#                               condition  n_counts  n_genes  mt_frac  cell_type
# index
# AAACATACCAAGCT-1-stimulated  stimulated    1160.0      589      0.0         NK
# AAACATACCCCTAC-1-stimulated  stimulated    1729.0      795      0.0  Dendritic
# AAACATACCCGTAA-1-stimulated  stimulated    1360.0      585      0.0       CD4T
# AAACATACCCTCGT-1-stimulated  stimulated    1442.0      732      0.0          B
# AAACATACGAGGTG-1-stimulated  stimulated    1237.0      546      0.0       CD4T
# ...                                 ...       ...      ...      ...        ...
# TTTGACTGGCGGAA-1-control        control    2505.0      821      0.0       CD8T
# TTTGACTGTCGTAG-1-control        control    3704.0     1101      0.0  CD14+Mono
# TTTGACTGTTACCT-1-control        control    2133.0      629      0.0  CD14+Mono
# TTTGCATGCTTCGC-1-control        control    2317.0      875      0.0          B
# TTTGCATGGTCCTC-1-control        control    1250.0      531      0.0          B
#
# ...

# %%
dat.X
# Out:
# <16893x6998 sparse matrix of type '<class 'numpy.float32'>'
# 	with 5533579 stored elements in Compressed Sparse Row format>

# %% [markdown]
# ### Output Data

# %%
dat.obs.to_csv("kang_obs.csv")
dat.var.to_csv("kang_var.csv")
np.savetxt('kang_X.csv',dat.X.toarray(),delimiter=',')
